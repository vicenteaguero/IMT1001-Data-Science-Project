# %%
import pandas as pd
from matplotlib import pyplot as plt
from random import randint
import EMNIST

# %%
pd.value_counts(EMNIST.dataframe_train["label"], sort=True)
# Out:
# 1     38374
# 7     35754
# 3     35143
# 0     34585
# 6     34232
#       ...
# 46     2491
# 20     2468
# 51     2448
# 60     2365
# 45     1896
# Name: label, Length: 62, dtype: int64

# %%
pd.value_counts(EMNIST.dataframe_test["label"])
# Out:
# 1     6330
# 7     6139
# 3     5969
# 2     5869
# 0     5778
#       ...
# 41     400
# 20     382
# 60     381
# 51     368
# 45     317
# Name: label, Length: 62, dtype: int64

# %%
fig = plt.figure(figsize=(15, 15))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for j in range(256):
    i = randint(0, len(EMNIST.x_train) - 1)
    ax = fig.add_subplot(16, 16, j + 1, xticks=[], yticks=[])
    ax.imshow(EMNIST.x_train[i], cmap=plt.cm.binary, interpolation='nearest')
ax.axis("on")
fig.savefig('EMNIST TRAIN.png', dpi=fig.dpi, edgecolor="purple")
